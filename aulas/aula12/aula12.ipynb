# %% [markdown]
# # PYTHON
#
# #### PROGRAMAÇÃO ORIENTADA A OBJETOS - POO (OOP - en)

# %% [markdown]
# JANELA
#     ATRIBUTOS / CARACTERISTICAS
#         - MATERIAL ->
#         - FORMATO ->
#         - COR ->
#         - ALTURA ->
#         - LARGURA ->
#         - COMPRIMENTO ->
#         - TEMPERATURA ->
#
#     COMPORTAMENTOS / METODOS /AÇÕES
#         - ABRIR()
#         - FECHAR()
#         - SUBIR()
#         - DESCER()
#         - VERIFICAR()
#
#     ESTADO
#         - conservação -> (nove, velha, conservada, quebrada)

# %% [markdown]
# PESSOA
#     - ATRIBUTOS
#         - ALTURA
#         - PESO
#         - ETNIA
#         - OLHOS
#         - ENDEREÇO
#         - TELEFONE
#         - PORTE
#         - CPF
#         - IDENTIDADE
#         - CABELO
#         - DATANASC
#         - NOMEMAE
#         - NOMEPAI
#
#     - MÉTODOS
#         - ANDAR()
#         - FALAR()
#         - CORRER()
#         - APRENDER()
#         - DIRIGIR()
#         ....
#
#
#     - ESTADO
#         - CANSADO
#         - CASADO
#
# ----------------------------------------------------------------
#
#     CARRO
#         ATRIBUTOS
#             - PREÇO
#             - ANO
#             - KM_RODADOS
#             - PORTAS
#             - TAMANHO_PORTAMA
#
#
#         MÉTODOS
#             - ACELERAR()
#             - FREIAR()
#             - DIREÇÃO
#             - ABRI_PORTA()
#             - LIGAR()
#             - DESLIGAR()
#
#         ESTADO
#             ligado/desligador
#             parado/andando
#             funcionando/ruim
#
#     ----------------------------------------------------------
#
#     CALENDARIO/EVENTO
#         ATRIBUTO
#             - DIA
#             - HORARIO
#             - MES
#             - LOCAL
#
#         METODOS
#             COMPRAR_INGRESSO()
#             MARCAR()
#             DESMARCAR()
#
#         ESTADO
#             status -> (ADIADO, ACONTECENDO, ATRASADO, FINALIZADO, CANCELADO)

# %% [markdown]
# # ESCOLA
#     CONTAS
#         ATRIBUTOS
#         - DATA_VENC
#         - VALOR
#         - STATUS
#
#     PROFESSOR
#         ATRIBUTOS
#         - MATERIA
#         - NOME
#         - SALARIO
#         - TELEFONE
#         - IDADE
#         - DATA_CONT
#
#         METODOS
#         - ENSINANDO()
#         - EM_AULA()
#         - DEMITIR()
#
#
#         ESTADO
#         - SITUAÇÃO -> (DEMITIDO)
#
#     ALUNOS
#         ATRIBUTOS
#         - SERIE
#         - NOME
#         - MENSALIDADE
#         - TELEFONE_RESP
#         - IDADE
#
#         METODOS
#             - LANCHANDO()
#             - ESTUDANDO()
#
#         ESTADO
#             situação -> (FALTA, NA AULA)
#
#     MATERIAIS
#         ATRIBUTOS
#         - VALOR
#         - DATA_COMP
#         - QNT
#
#     MATERIAIS_VENDA
#         ATRIBUTOS
#         - COD
#         - NOME
#         - VALOR
#         - QNT
#         - SETOR
#
#         METODOS
#         VERIFICA_ESTOQUE()
#         VERIFICA_SETOR()
#         VENDER()
#
#
#     FUNCIONARIOS
#         ATRIBUTOS
#             NOME
#             TELEFONE
#             SALARIO
#             DATA_CONT
#             AREA

# %% [markdown]
# CONSULTORIO MEDICO
#     MEDICOS
#         ATRIBUTOS
#             - NOME
#             - ESPEC
#             - SALARIO
#             - DIA_TRABA
#             - TELEFONE
#             - EMAIL
#             - CRM
#
#         METODOS
#             LISTAR_MEDICOS()
#             LISTAR_COMP()
#             QNT_ESP()
#
#         ESTADO
#
#     PACIENTE
#         ATRIBUTOS
#             - NOME
#             .....
#
#
#     CONSULTA
#         ATRIBUTOS
#         - NOME MEDICO
#         - CODMEDIC
#         - NOME PACIENTE
#         - VALOR
#         - DATA
#         - STATUS
#         - PRONTUARIO
#
#         METODOS
#          MARCAR()
#          LISTAR()
#          CONSULTAS_PACIENTES()
#          DESMARCAR
#
#     EQUIPAMENTOS
#         ATRI
#
#
#     FUNCIONAIROS
#         ATRIBUTOS
#
#
#
#     CONTAS
#         ATRIBUTOS

# %% [markdown]
# LOJA DE INFORMÁTICA
#
#     PRODUTOS
#         ATRIBUTOS
#             - VALOR
#             - PESO
#             - NOME
#             - CODIGO
#             - MARCA
#             - COR
#             - EPSCIFICAÇÃO
#
#         MÉTODOS
#             LISTAR()
#             VERIFICAR_EST()
#
#
#     VENDAS
#         ATRIBUTOS
#             - VALOR TOTAL
#             - PRODUTOS
#             - ENDERÇO
#             - FORMA
#             - VENDEDOR
#
#         METODOS
#             - COMPRAR()
#             - VERIFICAR()
#             - ALTERAR_STATUS()
#
#         ESTADO
#             STATUS -> (AGUARDANDO PG, ENVIADO, ENTREGUE, CANCELADO, PERDIDO, EM TROCA)
#
#
#     VENDEDOR
#         ATRIBUTOS ....

# %% [markdown]
# LOJA MCDONALDS
#     PRODUTOS
#         ATRIBUTOS
#             - CODIGO
#             - NOME
#             - VALOR
#             - DESCRIÇÃO
#             - TAM
#             - PESO
#             - QNT_ESTOQUE
#             - TIPO
#
#         METODO
#          - LISTAR_PRODUTOS()
#
#     VENDA
#         ATRIBUTO
#             - COD
#             - VALOR TOTAL
#             - LISTA PRODUTOS
#             - VENDEDOR
#             - FORMA_PG
#             - STATUS
#         METODO
#             ALTERAR_STATUS()
#             VENDER()
#         ESTADO
#             STATUS_VENDA
#
#     PROMOÇÃO
#         ATRIBUTOS
#             - COD
#             - NOME (AGOSTO20)
#             - VALOR_DESCONTO
#         METODOS
#             LISTA()
#
#
#         ESTADO
#             STATUS ->
#
#     FUNCIONARIOS
#
#     CONTAS
#
#     EQUIPAMENTOS
